# %% [markdown]
# <a href="https://colab.research.google.com/github/OlajideFemi/Data-Analysis-Projects/blob/main/Sunday_attendance_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# Read the text file
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r') as file:
    data = file.read()

# Define a regular expression pattern to match attendance counts
count_pattern = r'(?:First|Second|Final) count: (\d+)'

# Find all matches of the pattern in the text
attendance_counts = re.findall(count_pattern, data)

# Print the extracted attendance counts
print("Attendance Counts:")
for count in attendance_counts:
    print(count)
# Out:
# Attendance Counts:
# 151
# 134
# 190
# 87
# 132
# 131
# 112
# 102
# 86
# 104
# 61
# 89
# 151
# 84
# 60
# 62
# 71
# 89
# 58
# 63
# 65
# 60
# 84
# 75
# 67
# 109
# 85
# 80

# %%
import re

# Read the text file
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r') as file:
    data = file.read()

# Define a regular expression pattern to match attendance counts in the updated format
count_pattern = r'(?:First count|Final seated count)\*\n([\s\S]*?)\*Total: (\d+)'

# Find all matches of the pattern in the text
attendance_counts = re.findall(count_pattern, data)

# Print the extracted attendance counts
print("Attendance Counts:")
for match in attendance_counts:
    section_counts = match[0].strip().split('\n')
    print("Total:", match[1])
    for section_count in section_counts:
        print(section_count.strip())
    print()
# Out:
# Attendance Counts:
# Total: 145
# Section 1: 27/30
# Section 2:  28/39
# Section 3:  31/38
# Section 4: 26/30
# Instrumentalist: 4
# Back of the hall: 6
# Standing: 3
# Leavers: 15
# Children: 2
# Changing room: 2
# Entered after final count:
#
# Total: 156
# Section 1: 27/30
# Section 2:  29/39
# Section 3:  41/38
# Section 4: 26/30
# Instrumentalist: 4
# Back of the hall: 6
# Standing: 3
# Leavers: 15
# Children: 4
# Changing room: 2
# Entered after final count:
#
# Total: 123
# Section 1: 26/30
# Section 2:  29/39
# Section 3:  22/38
# Section 4: 22/30
# Instrumentalist: 4
# Back of the hall: 6
# Standing: 1
# Leavers: 7
# Children: 3
# Changing room: 3
# Entered after final count:
#
# Total: 139
# Section 1: 30/30
# Section 2:  32/39
# Section 3:  33/38
# Section 4: 19/30
# Instrumentalist: 4
# Back of the hall: 8
# Standing: 2
# Leavers: 2
# Children: 2
# Changing room:
# Entered after final count:
#
# *Total: / 152*
#
# *Final door Count: *
#
# New converts:
# First Timers:
# ...

# %%
import re

# Define the text data
text_data = """
Attendance Counts:
Total: 145
Section 1: 27/30
Section 2: 28/39
Section 3: 31/38
Section 4: 26/30
Instrumentalist: 4
Back of the hall: 6
Standing: 3
Leavers: 15
Children: 2
Changing room: 2
Entered after final count:

Total: 156
Section 1: 27/30
Section 2: 29/39
Section 3: 41/38
Section 4: 26/30
Instrumentalist: 4
Back of the hall: 6
Standing: 3
Leavers: 15
Children: 4
Changing room: 2
Entered after final count:

Total: 123
Section 1: 26/30
Section 2: 29/39
Section 3: 22/38
Section 4: 22/30
Instrumentalist: 4
Back of the hall: 6
Standing: 1
Leavers: 7
Children: 3
Changing room: 3
Entered after final count:

Total: 139
Section 1: 30/30
Section 2: 32/39
Section 3: 33/38
Section 4: 19/30
Instrumentalist: 4
Back of the hall: 8
Standing: 2
Leavers: 2
Children: 2
Changing room:
Entered after final count:

*Total: / 152*

*Final door Count: *

New converts:
First Timers:
Tithe:
"""

# Define a regular expression pattern to match attendance counts
count_pattern = r'Total: (\d+)\n(?:Section \d+: \d+/\d+\n)*'

# Find all matches of the pattern in the text
attendance_counts = re.findall(count_pattern, text_data)

# Print the extracted attendance counts
print("Attendance Counts:")
for count in attendance_counts:
    print("Total:", count)
# Out:
# Attendance Counts:
# Total: 145
# Total: 156
# Total: 123
# Total: 139

# %%
from datetime import datetime, timedelta

# Define the start and end dates
start_date = datetime.strptime('02/12/2022', '%d/%m/%Y')
end_date = datetime.strptime('24/04/2024', '%d/%m/%Y')

# Initialize a counter for Sundays
sundays_count = 0

# Iterate over each date in the range
current_date = start_date
while current_date <= end_date:
    # Check if the current date is a Sunday (weekday() returns 6 for Sunday)
    if current_date.weekday() == 6:
        sundays_count += 1
    # Move to the next day
    current_date += timedelta(days=1)

# Print the number of Sundays
print("Number of Sundays between", start_date.strftime('%d/%m/%Y'), "and", end_date.strftime('%d/%m/%Y'), ":", sundays_count)
# Out:
# Number of Sundays between 02/12/2022 and 24/04/2024 : 73

# %%
import re
from datetime import datetime

# Read the text file
#with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r') as file:
#    data = file.readlines()

# Define a regular expression pattern to match date formats
#date_pattern = r'(\d{2}/\d{2}/\d{4})'

# Function to check if a given date is a Sunday
#def is_sunday(date_str):
#    date_obj = datetime.strptime(date_str, '%d/%m/%Y')
#    return date_obj.weekday() == 6  # 6 represents Sunday

# Filter out messages sent on Sundays
#sunday_messages = [line.strip() for line in data if re.search(date_pattern, line) and is_sunday(re.search(date_pattern, line).group(1))]

# Print the filtered messages
#for message in sunday_messages:
#    print(message)

# %%
# Define the output file path
#output_file_path = 'sunday_messages.txt'

# Write the filtered messages to the output file
#with open(output_file_path, 'w') as output_file:
#    for message in sunday_messages:
#        output_file.write(message + '\n')

#print(f"Filtered messages saved to {output_file_path}")

# %%
import re

# Read the text file
with open('sunday_messages.txt', 'r') as file:
    data = file.read()

# Define a regular expression pattern to match attendance totals
attendance_pattern = r'Total: (\d+)'

# Find all matches of the pattern in the text
attendance_totals = re.findall(attendance_pattern, data)

# Convert attendance totals to integers
attendance_totals = [int(total) for total in attendance_totals]

# Print the extracted attendance totals
print("Attendance Totals:")
for total in attendance_totals:
    print(total)
# Out:
# Attendance Totals:

# %%
import re

# Read the text file
with open('sunday_messages_counts_filtered.txt', 'r') as file:
    data = file.read()

# Define a regular expression pattern to match the counts
count_pattern = r'(?:(?:First|Second|Final) count|Final seated count):? (\d+)'
# Find all matches of the pattern in the text
counts = re.findall(count_pattern, data)

# Create a list to store the filtered counts
filtered_counts = []

# Iterate through the matches and append "NA" for missing counts
for count in counts:
    if count.isdigit():
        filtered_counts.append(int(count))
    else:
        filtered_counts.append("NA")

# Print the filtered counts
print(filtered_counts)

# Write the filtered counts to a file
with open('filtered_counts.txt', 'w') as file:
    for count in filtered_counts:
        file.write(str(count) + '\n')
# Out:
# [151, 134, 90, 190, 132, 131, 131, 112, 102, 86, 113, 79, 104, 109, 92, 94, 76, 95, 71, 151, 128, 108, 92, 77, 89, 76, 63, 65, 65, 84, 86, 90, 109, 109, 110, 112, 85, 113, 62, 70, 64]

# %%
import re

# Read the text file
with open('sunday_messages_counts_filtered.txt', 'r') as file:
    data = file.read()

# Define a regular expression pattern to match the counts
count_pattern = r'(?:(?:Final) count|Final seated count):? (\d+)'

# Find all matches of the pattern in the text
counts = re.findall(count_pattern, data)

# Create a list to store the filtered counts
filtered_counts = []

# Iterate through the matches and append "NA" for missing counts
for count in counts:
    if count.isdigit():
        filtered_counts.append(int(count))
    else:
        filtered_counts.append("NA")

# Print the filtered counts
print(filtered_counts)

# Write the filtered counts to a file
with open('filtered_counts.txt', 'w') as file:
    for count in filtered_counts:
        file.write(str(count) + '\n')
# Out:
# [151, 134, 90, 190, 131, 131, 112, 102, 113, 104, 109, 94, 95, 151]

# %%
import re

# Read the text file
with open('sunday_messages_counts_filtered.txt', 'r') as file:
    data = file.read()

# Define a regular expression pattern to match the counts
count_pattern = r'(?:(?:Second) count|Final seated count):? (\d+)'

# Find all matches of the pattern in the text
counts = re.findall(count_pattern, data)

# Create a list to store the filtered counts
filtered_counts = []

# Iterate through the matches and append "NA" for missing counts
for count in counts:
    if count.isdigit():
        filtered_counts.append(int(count))
    else:
        filtered_counts.append("NA")

# Print the filtered counts
print(filtered_counts)

# Write the filtered counts to a file
with open('filtered_counts.txt', 'w') as file:
    for count in filtered_counts:
        file.write(str(count) + '\n')
# Out:
# [132, 86, 79, 92, 71, 128, 108, 92, 77, 89, 76, 65, 84, 86, 90, 109, 109, 110, 112, 113]

# %%
import re

# Read the text file
with open('sunday_messages_counts_filtered.txt', 'r') as file:
    data = file.read()

# Define a regular expression pattern to match the counts
count_pattern = r'(?:(?:First) count|Final seated count):? (\d+)'

# Find all matches of the pattern in the text
counts = re.findall(count_pattern, data)

# Create a list to store the filtered counts
filtered_counts = []

# Iterate through the matches and append "NA" for missing counts
for count in counts:
    if count.isdigit():
        filtered_counts.append(int(count))
    else:
        filtered_counts.append("NA")

# Print the filtered counts
print(filtered_counts)

# Write the filtered counts to a file
with open('filtered_counts.txt', 'w') as file:
    for count in filtered_counts:
        file.write(str(count) + '\n')
# Out:
# [76, 63, 65, 85, 62, 70, 64]

# %%
import matplotlib.pyplot as plt

# Read the filtered counts from the file
with open('filtered_counts.txt', 'r') as file:
    filtered_counts = [int(line.strip()) if line.strip().isdigit() else None for line in file]

# Generate x-axis labels (indices of counts)
x_labels = range(1, len(filtered_counts) + 1)

# Create the plot
plt.figure(figsize=(10, 6))
plt.bar(x_labels, filtered_counts, color='skyblue')

# Set plot title and labels
plt.title('Attendance Counts Over Time')
plt.xlabel('Weeks')
plt.ylabel('Attendance Count')

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Read the filtered counts from the file
with open('filtered_counts.txt', 'r') as file:
    filtered_counts = [int(line.strip()) if line.strip().isdigit() else None for line in file]

# Generate x-axis labels (indices of counts)
x_labels = range(1, len(filtered_counts) + 1)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_labels, filtered_counts, marker='o', color='skyblue', linestyle='-')

# Set plot title and labels
plt.title('Attendance Counts Over Time')
plt.xlabel('Weeks')
plt.ylabel('Attendance Count')

# Add gridlines
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.yticks(range(0, 201, 20))  # Set y-axis ticks from 0 to 200 with step 20

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re

# Read the text file and extract dates and counts
with open('sunday_messages_counts_filtered.txt', 'r') as file:
    data = file.readlines()

dates = []
counts = []

for line in data:
    match = re.search(r'^(\d{2}/\d{2}/\d{4}),.*: (\d+)$', line)
    if match:
        dates.append(match.group(1))
        counts.append(int(match.group(2)))

# Create a DataFrame
#df = pd.DataFrame({'Date': pd.to_datetime(dates, format=%d\%m\%Y), 'Count': counts})
df = pd.DataFrame({'Date': pd.to_datetime(dates, format='%d/%m/%Y'), 'Count': counts})


# Anomalies to highlight
anomalies = {
    'Missing Counts': ['25/12/2022', '01/01/2023', '19/02/2023', '05/03/2023', '09/04/2023'],
    'Different Counts': ['15/01/2023', '28/05/2023', '06/08/2023', '14/05/2023', '07/10/2023'],
    'Initial and Final Counts': ['16/07/2023', '10/03/2024', '24/03/2024']
}

# Plot the attendance counts
plt.figure(figsize=(12, 6))

# Plot the line plot
plt.plot(df['Date'], df['Count'], color='blue', marker='o', label='Attendance Counts')

# Highlight anomalies
for anomaly_type, anomaly_dates in anomalies.items():
    for date in anomaly_dates:
        if date in df['Date'].astype(str).values:
            count = df.loc[df['Date'] == date, 'Count'].values[0]
            plt.scatter(pd.to_datetime(date), count, color='red', label=anomaly_type)
            plt.annotate(anomaly_type, (pd.to_datetime(date), count), textcoords="offset points", xytext=(0, 10), ha='center', fontsize=8, color='red')

plt.title('Attendance Counts Over Time with Anomalies Highlighted')
plt.xlabel('Date')
plt.ylabel('Attendance Count')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re

# Read the text file and extract dates and counts
with open('sunday_messages_counts_filtered.txt', 'r') as file:
    data = file.readlines()

dates = []
counts = []

for line in data:
    match = re.search(r'(\d{2}/\d{2}/\d{4}).*-.*: (\d+)', line)
    if match:
        dates.append(match.group(1))
        counts.append(int(match.group(2)))

# Create a DataFrame
df = pd.DataFrame({'Date': pd.to_datetime(dates, format='%d/%m/%Y'), 'Count': counts})

# Anomalies to highlight
anomalies = {
    'Missing Counts': ['25/12/2022', '01/01/2023', '19/02/2023', '05/03/2023', '09/04/2023'],
    'Different Counts': ['15/01/2023', '28/05/2023', '06/08/2023', '14/05/2023', '07/10/2023'],
    'Initial and Final Counts': ['16/07/2023', '10/03/2024', '24/03/2024']
}

# Plot the attendance counts
plt.figure(figsize=(12, 6))

# Plot the line plot
plt.plot(df['Date'], df['Count'], color='blue', marker='o', label='Attendance Counts')
#plt.plot(x_labels, filtered_counts, marker='o', color='skyblue', linestyle='-')

# Highlight anomalies
for anomaly_type, anomaly_dates in anomalies.items():
    for date in anomaly_dates:
        if date in df['Date'].astype(str).values:
            count = df.loc[df['Date'] == pd.to_datetime(date, format='%d/%m/%Y'), 'Count'].values[0]
            plt.scatter(pd.to_datetime(date, format='%d/%m/%Y'), count, color='red', label=anomaly_type)
            plt.annotate(anomaly_type, (pd.to_datetime(date, format='%d/%m/%Y'), count), textcoords="offset points", xytext=(0, 10), ha='center', fontsize=8, color='red')

plt.title('Attendance Counts Over Time with Anomalies Highlighted')
plt.xlabel('Date')
plt.ylabel('Attendance Count')
plt.yticks(range(0, 201, 20))  # Set y-axis ticks from 0 to 200 with step 20
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# To perform a critical analysis of the data and identify days with different counts, we need to examine the variations in attendance counts and understand the context behind them. Here's a breakdown of the data and some insights:
#
# 1. **Consistent Counts:** Some days have consistent attendance counts throughout the day, indicated by repeated messages from the same person with the same count. For example:
#    - 04/12/2022: Final count: 151
#    - 11/12/2022: Final count: 134
#    - 29/01/2023: Final count: 190
#    - 26/03/2023: Final count: 210
#    - 23/04/2023: Final count: 112
#
# 2. **Missing Counts:** Some days have missing counts, indicated by "NA" in the messages. This suggests a lack of data or possibly irregular attendance tracking. For example:
#    - 25/12/2022: NA
#    - 01/01/2023: NA
#    - 19/02/2023: NA
#    - 05/03/2023: NA
#    - 09/04/2023: NA
#
# 3. **Inconsistent Counts:** Some days have different counts reported by different individuals or multiple counts reported throughout the day. This might indicate discrepancies in counting methods or fluctuations in attendance. For example:
#    - 15/01/2023: Head count 73 (indicates a different counting method)
#    - 28/05/2023: Second count: 86 (different count from Eni Aroyewun's Final count)
#    - 06/08/2023: 96 (different format without mentioning Final count)
#    - 14/05/2023: Final count: 102 (lower count than usual)
#    - 07/10/2023: Second count 128 (higher count than usual)
#
# 4. **Initial and Final Counts:** Some days have multiple counts, where the first count might represent an initial estimate and the final count represents the actual attendance after adjustments. For example:
#    - 16/07/2023: First Count: 77
#    - 10/03/2024: First count: 85
#    - 24/03/2024: Second count 113 (suggests adjustment from the initial count)
#
# 5. **Special Occasions:** Some days might have unusual counts due to special events, holidays, or other factors. For example, counts on Christmas, New Year's Day, or Easter Sunday might differ from regular Sundays.
#
# By analyzing these patterns, it's possible to identify trends, anomalies, and areas for improvement in attendance tracking and reporting processes. It's important to ensure consistency, accuracy, and transparency in counting methods to obtain reliable attendance data for decision-making and planning purposes.

# %%
# Define a function to check if a count is realistic
def is_realistic_count(count):
    # Define a threshold for realistic counts
    min_count = 50  # Minimum realistic count
    max_count = 300  # Maximum realistic count

    # Check if the count is within the threshold
    if min_count <= count <= max_count:
        return True
    else:
        return False

# Filter out realistic counts
realistic_counts = [count for count in filtered_counts if is_realistic_count(count)]

# Print the realistic counts
print("Realistic Counts:")
print(realistic_counts)


# Write the Realistic Counts to a file
with open('Realistic Counts.txt', 'w') as file:
    for count in filtered_counts:
        file.write(str(count) + '\n')
# Out:
# Realistic Counts:
# [151, 134, 90, 190, 132, 131, 131, 112, 102, 86, 113, 79, 104, 109, 92, 94, 76, 95, 71, 151, 128, 108, 92, 77, 89, 76, 63, 65, 65, 84, 86, 90, 109, 109, 110, 112, 85, 113, 62, 70, 64]

# %%
import matplotlib.pyplot as plt

# Realistic counts
realistic_counts = [151, 134, 90, 190, 132, 131, 131, 112, 102, 86, 113, 79, 104, 109, 92, 94, 76, 95, 71, 151, 128, 108, 92, 77, 89, 76, 63, 65, 65, 84, 86, 90, 109, 109, 110, 112, 85, 113, 62, 70, 64]

# Dates corresponding to the counts (you can replace this with your actual date values)
dates = range(1, len(realistic_counts) + 1)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(dates, realistic_counts, marker='o', linestyle='-')
plt.yticks(range(0, 201, 20))  # Set y-axis ticks from 0 to 200 with step 20
plt.title('Realistic Attendance Counts Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Realistic counts
realistic_counts = [151, 134, 90, 190, 132, 131, 131, 112, 102, 86, 113, 79, 104, 109, 92, 94, 76, 95, 71, 151, 128, 108, 92, 77, 89, 76, 63, 65, 65, 84, 86, 90, 109, 109, 110, 112, 85, 113, 62, 70, 64]

# Dates corresponding to the counts (you can replace this with your actual date values)
dates = range(1, len(realistic_counts) + 1)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(dates, realistic_counts, marker='o', linestyle='-')
plt.title('Realistic Attendance Counts Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.xticks(range(0, len(realistic_counts) + 1, 1))  # Set x-axis ticks from 0 to 200 with step 10
plt.yticks(range(0, 201, 20))  # Set y-axis ticks from 0 to 200 with step 20
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Read the data from sunday_messages.txt
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r') as file:
    data = file.readlines()

# Initialize dictionaries to store counts
counts_dict = {'Date': [], 'Head Count': [], 'Second Count': [], 'Final Count': [], 'First Count': [], 'Attendance Counts': [], 'Total': []}

# Define regular expressions to match different types of counts
count_patterns = {
    'Head Count': r'Head count (\d+)',
    'Second Count': r'Second count (\d+)',
    'Final Count': r'Final count: (\d+)',
    'First Count': r'First count (\d+)',
    'Attendance Counts': r'Attendance Counts: (\d+)',
    'Total': r'Total: (\d+)'
}

# Iterate over each line in the data
for line in data:
    # Extract the date
    date = line.split(' - ')[0]
    counts_dict['Date'].append(date)

    # Iterate over each count type
    for count_type, pattern in count_patterns.items():
        # Try to find the count in the line
        match = re.search(pattern, line)
        if match:
            count = match.group(1)
        else:
            count = None

        # Append the count to the respective list
        counts_dict[count_type].append(count)

# Create a DataFrame from the dictionary
df = pd.DataFrame(counts_dict)

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Display the DataFrame
print(df)
# Out:
#                                                    Head Count Second Count  \
# Date
# 02/12/2022, 1:30 pm                                      None         None
# 02/10/2021, 1:42 pm                                      None         None
# 02/12/2022, 1:30 pm                                      None         None
# 02/12/2022, 1:30 pm                                      None         None
# \n                                                       None         None
# ...                                                       ...          ...
# Passcode: gTu2BZ\n                                       None         None
# 23/04/2024, 7:36 pm                                      None         None
# 24/04/2024, 9:31 pm                                      None         None
# \n                                                       None         None
# Don’t be happy just coming church and warming t...       None         None
#
# ...

# %%
import pandas as pd
import re

# Read the data from WhatsApp_Chat_with_FLA_Ushers_City.txt
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r', encoding='utf-8') as file:
    data = file.readlines()

# Initialize dictionaries to store counts
counts_dict = {'Date': [], 'Head Count': [], 'Second Count': [], 'Final Count': [], 'First Count': [], 'Attendance Counts': [], 'Total': []}

# Define regular expressions to match different types of counts
count_patterns = {
    'Head Count': r'Head count (\d+)',
    'Second Count': r'Second count: (\d+)',
    'Final Count': r'Final count: (\d+)',
    'First Count': r'First count: (\d+)',
    'Attendance Counts': r'Attendance Counts: (\d+)',
    'Total': r'Total: (\d+)'
}

# Iterate over each line in the data
for line in data:
    # Extract the date
    date_match = re.search(r'(\d{2}/\d{2}/\d{4}, \d{1,2}:\d{2}\u200b?[ap]m)', line)
    if date_match:
        date = date_match.group(1)
        counts_dict['Date'].append(date)

        # Iterate over each count type
        for count_type, pattern in count_patterns.items():
            # Try to find the count in the line
            match = re.search(pattern, line)
            if match:
                count = match.group(1)
            else:
                count = None

            # Append the count to the respective list
            counts_dict[count_type].append(count)

# Create a DataFrame from the dictionary
df = pd.DataFrame(counts_dict)

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Display the DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: [Head Count, Second Count, Final Count, First Count, Attendance Counts, Total]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [Head Count, Second Count, Final Count, First Count, Attendance Counts, Total]
# Index: []

# %%
import pandas as pd
import re

# Read the data from WhatsApp_Chat_with_FLA_Ushers_City.txt
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r', encoding='utf-8') as file:
    data = file.readlines()

# Initialize dictionaries to store counts
counts_dict = {'Date': [], 'Head Count': [], 'Second Count': [], 'Final Count': [], 'First Count': [], 'Attendance Counts': [], 'Total': []}

# Define regular expressions to match different types of counts
count_patterns = {
    'Head Count': r'Head count (\d+)',
    'Second Count': r'Second count: (\d+)',
    'Final Count': r'Final count: (\d+)',
    'First Count': r'First count: (\d+)',
    'Attendance Counts': r'Attendance Counts: (\d+)',
    'Total': r'Total: (\d+)'
}

# Iterate over each line in the data
for line in data:
    # Extract the date
    date_match = re.search(r'(\d{2}/\d{2}/\d{4}, \d{1,2}:\d{2}\u200b?[ap]m)', line)
    if date_match:
        date = date_match.group(1)
        counts_dict['Date'].append(date)

        # Iterate over each count type
        for count_type, pattern in count_patterns.items():
            # Try to find the count in the line
            match = re.search(pattern, line)
            if match:
                count = match.group(1)
            else:
                count = None

            # Append the count to the respective list
            counts_dict[count_type].append(count)

# Create a DataFrame from the dictionary
df = pd.DataFrame(counts_dict)

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Display the DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: [Head Count, Second Count, Final Count, First Count, Attendance Counts, Total]
# Index: []

# %%
import pandas as pd
import re

# Initialize lists to store dates and 'First Count' values
dates = []
first_counts = []

# Open the WhatsApp chat file and read each line
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r', encoding='utf-8') as file:
    for line in file:
        # Extract the date in the format d/m/y
        date_match = re.search(r'(\d{1,2}/\d{1,2}/\d{2,4})', line)
        if date_match:
            dates.append(date_match.group(1))

        # Extract 'First Count' values
        first_count_match = re.search(r'First count: (\d+)', line)
        if first_count_match:
            first_counts.append(int(first_count_match.group(1)))

# Create a DataFrame from the extracted data
df = pd.DataFrame({'Date': dates, 'First Count': first_counts})

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-d6e289802138> in <cell line: 22>()
#      20
#      21 # Create a DataFrame from the extracted data
# ---> 22 df = pd.DataFrame({'Date': dates, 'First Count': first_counts})
#      23
#      24 # Display the DataFrame
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     707         elif isinstance(data, dict):
#     708             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710         elif isinstance(data, ma.MaskedArray):
#     711             from numpy.ma import mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
import pandas as pd
import re

# Initialize lists to store dates and 'First Count' values
dates = []
first_counts = []

# Open the WhatsApp chat file and read each line
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r', encoding='utf-8') as file:
    for line in file:
        # Extract the date in the format d/m/y
        date_match = re.search(r'(\d{1,2}/\d{1,2}/\d{2,4})', line)
        if date_match:
            dates.append(date_match.group(1))
        else:
            dates.append(None)  # Append None if date is not found

        # Extract 'First Count' values
        first_count_match = re.search(r'First count: (\d+)', line)
        if first_count_match:
            first_counts.append(int(first_count_match.group(1)))
        else:
            first_counts.append(None)  # Append None if 'First Count' is not found

# Create a DataFrame from the extracted data
df = pd.DataFrame({'Date': dates, 'First Count': first_counts})

# Display the DataFrame
print(df)
# Out:
#             Date  First Count
# 0     02/12/2022          NaN
# 1     02/10/2021          NaN
# 2     02/12/2022          NaN
# 3     02/12/2022          NaN
# 4           None          NaN
# ...          ...          ...
# 6395        None          NaN
# 6396  23/04/2024          NaN
# 6397  24/04/2024          NaN
# 6398        None          NaN
# 6399        None          NaN
#
# [6400 rows x 2 columns]

# %%
df.to_csv('filter.csv')

# %%
import pandas as pd
import re

# Initialize lists to store dates and 'Second Count' values
dates = []
Second_counts = []

# Open the WhatsApp chat file and read each line
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r', encoding='utf-8') as file:
    for line in file:
        # Extract the date in the format d/m/y
        date_match = re.search(r'(\d{1,2}/\d{1,2}/\d{2,4})', line)
        if date_match:
            dates.append(date_match.group(1))
        else:
            dates.append(None)  # Append None if date is not found

        # Extract 'Second Count' values
        Second_count_match = re.search(r'Second count: (\d+)', line)
        if Second_count_match:
            Second_counts.append(int(Second_count_match.group(1)))
        else:
            Second_counts.append(None)  # Append None if 'Second Count' is not found

# Create a DataFrame from the extracted data
df = pd.DataFrame({'Date': dates, 'Second Count': Second_counts})

# Display the DataFrame
print(df)

df.to_csv('filter1.csv')
# Out:
#             Date  Second Count
# 0     02/12/2022           NaN
# 1     02/10/2021           NaN
# 2     02/12/2022           NaN
# 3     02/12/2022           NaN
# 4           None           NaN
# ...          ...           ...
# 6395        None           NaN
# 6396  23/04/2024           NaN
# 6397  24/04/2024           NaN
# 6398        None           NaN
# 6399        None           NaN
#
# [6400 rows x 2 columns]

# %%
import pandas as pd
import re

# Initialize lists to store dates and 'Head Count' values
dates = []
Head_counts = []

# Open the WhatsApp chat file and read each line
with open('WhatsApp_Chat_with_FLA_Ushers_City.txt', 'r', encoding='utf-8') as file:
    for line in file:
        # Extract the date in the format d/m/y
        date_match = re.search(r'(\d{1,2}/\d{1,2}/\d{2,4})', line)
        if date_match:
            dates.append(date_match.group(1))
        else:
            dates.append(None)  # Append None if date is not found

        # Extract 'Head Count' values
        Head_count_match = re.search(r'Head count: (\d+)', line)
        if Head_count_match:
            Head_counts.append(int(Head_count_match.group(1)))
        else:
            Head_counts.append(None)  # Append None if 'Head Count' is not found

# Create a DataFrame from the extracted data
df = pd.DataFrame({'Date': dates, 'Head Count': Head_counts})

# Display the DataFrame
print(df)

df.to_csv('filter3.csv')
# Out:
#             Date Head Count
# 0     02/12/2022       None
# 1     02/10/2021       None
# 2     02/12/2022       None
# 3     02/12/2022       None
# 4           None       None
# ...          ...        ...
# 6395        None       None
# 6396  23/04/2024       None
# 6397  24/04/2024       None
# 6398        None       None
# 6399        None       None
#
# [6400 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data provided by the user
data = {
    "Date": [
        "04/12/2022", "11/12/2022", "18/12/2022", "08/01/2023", "15/01/2023", "29/01/2023", "05/02/2023",
        "12/02/2023", "26/02/2023", "12/03/2023", "26/03/2023", "02/04/2023", "23/04/2023", "14/05/2023",
        "21/05/2023", "28/05/2023", "04/06/2023", "11/06/2023", "18/06/2023", "25/06/2023", "02/07/2023",
        "09/07/2023", "16/07/2023", "23/07/2023", "30/07/2023", "06/08/2023", "20/08/2023", "27/08/2023",
        "03/09/2023", "10/09/2023", "17/09/2023", "24/09/2023", "01/10/2023", "08/10/2023", "15/10/2023",
        "22/10/2023", "29/10/2023", "05/11/2023", "12/11/2023", "19/11/2023", "26/11/2023", "03/12/2023",
        "10/12/2023", "17/12/2023", "24/12/2023", "14/01/2024", "21/01/2024", "28/01/2024", "11/02/2024",
        "18/02/2024", "25/02/2024", "03/03/2024", "10/03/2024", "17/03/2024", "24/03/2024", "07/04/2024",
        "14/04/2024", "21/04/2024"
    ],
    "Final count": [
        151, 134, 90, 213, 73, 190, 300, 219, 255, 136, 210, 131, 112, 102, 86, 138, 418, 113, 150, 104, 109,
        160, 77, 168, 94, 150, 76, 95, 122, 95, 151, 195, 123, 223, 98, 192, 152, 139, 160, 134, 63, 65, 155,
        113, 79, 151, 140, 143, 184, 176, 190, 174, 85, 75, 193, 62, 70, 64
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# Sort the DataFrame by Date
df = df.sort_values('Date')

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Final count'], marker='o', linestyle='-')
plt.title('Final Count Over Time')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=90)
plt.yticks(range(0,450,50))
plt.tight_layout()
plt.show()

# %%
pip install ace

# %%
# Step 1: Trend Analysis - Seasonal Trends
# Aggregate data monthly
df_monthly = df.resample('M', on='Date').sum()

# Plot monthly aggregated data
plt.figure(figsize=(10, 5))
plt.plot(df_monthly.index, df_monthly['Final count'], marker='o', linestyle='-')
plt.title('Monthly Aggregated Final Count')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Step 1: Trend Analysis - Moving Average
# Calculate 4-week moving average
df['4_week_MA'] = df['Final count'].rolling(window=4).mean()

# Plot moving average
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Final count'], marker='o', linestyle='-', label='Final Count')
plt.plot(df['Date'], df['4_week_MA'], linestyle='-', color='orange', label='4-Week Moving Average')
plt.title('Final Count with 4-Week Moving Average')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Step 2: Correlation Analysis (Conceptual)
# Since we do not have external data (weather, holidays), we'll discuss this conceptually

# Step 3: Segmentation Analysis
# Define thresholds for high and low attendance
high_threshold = df['Final count'].quantile(0.75)
low_threshold = df['Final count'].quantile(0.25)

# Segment data into high and low attendance periods
df['segment'] = pd.cut(df['Final count'], bins=[-np.inf, low_threshold, high_threshold, np.inf], labels=['Low', 'Medium', 'High'])

# Display segmented data
import ace_tools as tools; tools.display_dataframe_to_user(name="Segmented Attendance Data", dataframe=df)

# Step 4: Year-over-Year Comparison
# Extract year and month for grouping
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Group by year and month
df_yoy = df.groupby(['Year', 'Month'])['Final count'].sum().unstack(level=0)

# Plot Year-over-Year comparison
df_yoy.plot(figsize=(10, 5), marker='o')
plt.title('Year-over-Year Comparison of Final Count')
plt.xlabel('Month')
plt.ylabel('Final Count')
plt.grid(True)
plt.legend(title='Year')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-e0cef108ac4b> in <cell line: 45>()
#      43
#      44 # Display segmented data
# ---> 45 import ace_tools as tools; tools.display_dataframe_to_user(name="Segmented Attendance Data", dataframe=df)
#      46
#      47 # Step 4: Year-over-Year Comparison
#
# ModuleNotFoundError: No module named 'ace_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from sklearn.cluster import KMeans

# K-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(df[['Final count']])

# Plotting clusters
plt.figure(figsize=(10, 5))
for cluster in df['cluster'].unique():
    cluster_data = df[df['cluster'] == cluster]
    plt.scatter(cluster_data['Date'], cluster_data['Final count'], label=f'Cluster {cluster}')

plt.title('K-means Clustering of Attendance Data')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Display clustered data
tools.display_dataframe_to_user(name="Clustered Attendance Data", dataframe=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-28f012508d0f> in <cell line: 23>()
#      21
#      22 # Display clustered data
# ---> 23 tools.display_dataframe_to_user(name="Clustered Attendance Data", dataframe=df)
#      24
#
# NameError: name 'tools' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import IsolationForest
from statsmodels.tsa.arima.model import ARIMA
from sklearn.cluster import KMeans
import warnings

# Data provided by the user
data = {
    "Date": [
        "04/12/2022", "11/12/2022", "18/12/2022", "08/01/2023", "15/01/2023", "29/01/2023", "05/02/2023",
        "12/02/2023", "26/02/2023", "12/03/2023", "26/03/2023", "02/04/2023", "23/04/2023", "14/05/2023",
        "21/05/2023", "28/05/2023", "04/06/2023", "11/06/2023", "18/06/2023", "25/06/2023", "02/07/2023",
        "09/07/2023", "16/07/2023", "23/07/2023", "30/07/2023", "06/08/2023", "20/08/2023", "27/08/2023",
        "03/09/2023", "10/09/2023", "17/09/2023", "24/09/2023", "01/10/2023", "08/10/2023", "15/10/2023",
        "22/10/2023", "29/10/2023", "05/11/2023", "12/11/2023", "19/11/2023", "26/11/2023", "03/12/2023",
        "10/12/2023", "17/12/2023", "24/12/2023", "14/01/2024", "21/01/2024", "28/01/2024", "11/02/2024",
        "18/02/2024", "25/02/2024", "03/03/2024", "10/03/2024", "17/03/2024", "24/03/2024", "07/04/2024",
        "14/04/2024", "21/04/2024"
    ],
    "Final count": [
        151, 134, 90, 213, 73, 190, 300, 219, 255, 136, 210, 131, 112, 102, 86, 138, 418, 113, 150, 104, 109,
        160, 77, 168, 94, 150, 76, 95, 122, 95, 151, 195, 123, 223, 98, 192, 152, 139, 160, 134, 63, 65, 155,
        113, 79, 151, 140, 143, 184, 176, 190, 174, 85, 75, 193, 62, 70, 64
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# Sort the DataFrame by Date
df = df.sort_values('Date')

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Final count'], marker='o', linestyle='-')
plt.title('Final Count Over Time')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=90)
plt.yticks(range(0, 450, 50))
plt.tight_layout()
plt.show()

# Step 1: Trend Analysis - Seasonal Trends
# Aggregate data monthly
df_monthly = df.resample('M', on='Date').sum()

# Plot monthly aggregated data
plt.figure(figsize=(10, 5))
plt.plot(df_monthly.index, df_monthly['Final count'], marker='o', linestyle='-')
plt.title('Monthly Aggregated Final Count')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Step 1: Trend Analysis - Moving Average
# Calculate 4-week moving average
df['4_week_MA'] = df['Final count'].rolling(window=4).mean()

# Plot moving average
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Final count'], marker='o', linestyle='-', label='Final Count')
plt.plot(df['Date'], df['4_week_MA'], linestyle='-', color='orange', label='4-Week Moving Average')
plt.title('Final Count with 4-Week Moving Average')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Step 2: Correlation Analysis (Conceptual)
# Since we do not have external data (weather, holidays), we'll discuss this conceptually

# Step 3: Segmentation Analysis
# Define thresholds for high and low attendance
high_threshold = df['Final count'].quantile(0.75)
low_threshold = df['Final count'].quantile(0.25)

# Segment data into high and low attendance periods
df['segment'] = pd.cut(df['Final count'], bins=[-np.inf, low_threshold, high_threshold, np.inf], labels=['Low', 'Medium', 'High'])

# Print segmented data
print("Segmented Attendance Data:")
print(df)

# Step 4: Year-over-Year Comparison
# Extract year and month for grouping
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Group by year and month
df_yoy = df.groupby(['Year', 'Month'])['Final count'].sum().unstack(level=0)

# Plot Year-over-Year comparison
df_yoy.plot(figsize=(10, 5), marker='o')
plt.title('Year-over-Year Comparison of Final Count')
plt.xlabel('Month')
plt.ylabel('Final Count')
plt.grid(True)
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# Isolation Forest for anomaly detection
iso_forest = IsolationForest(contamination=0.1, random_state=42)
df['anomaly_if'] = iso_forest.fit_predict(df[['Final count']])

# Anomalies detected by Isolation Forest
anomalies_if = df[df['anomaly_if'] == -1]

# Print the anomalies
print("Isolation Forest Detected Anomalies:")
print(anomalies_if)

# Plotting with Isolation Forest anomalies highlighted
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Final count'], marker='o', linestyle='-', label='Final Count')
plt.scatter(anomalies_if['Date'], anomalies_if['Final count'], color='red', label='Anomalies (Isolation Forest)', zorder=5)
plt.title('Final Count Over Time with Isolation Forest Anomalies Highlighted')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Suppress warnings from the ARIMA model
warnings.filterwarnings("ignore")

# Fit ARIMA model
model = ARIMA(df.set_index('Date')['Final count'], order=(5, 1, 0))
model_fit = model.fit()

# Forecast the next 12 periods (weeks)
forecast = model_fit.forecast(steps=12)

# Plot the original data and forecast
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Final count'], marker='o', linestyle='-', label='Actual')
plt.plot(forecast.index, forecast, marker='o', linestyle='-', color='orange', label='Forecast')
plt.title('ARIMA Model Forecast')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# K-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(df[['Final count']])

# Plotting clusters
plt.figure(figsize=(10, 5))
for cluster in df['cluster'].unique():
    cluster_data = df[df['cluster'] == cluster]
    plt.scatter(cluster_data['Date'], cluster_data['Final count'], label=f'Cluster {cluster}')

plt.title('K-means Clustering of Attendance Data')
plt.xlabel('Date')
plt.ylabel('Final Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Print clustered data
print("Clustered Attendance Data:")
print(df)
# Out:
# Segmented Attendance Data:
#          Date  Final count  4_week_MA segment
# 0  2022-12-04          151        NaN  Medium
# 1  2022-12-11          134        NaN  Medium
# 2  2022-12-18           90        NaN     Low
# 3  2023-01-08          213     147.00    High
# 4  2023-01-15           73     127.50     Low
# 5  2023-01-29          190     141.50    High
# 6  2023-02-05          300     194.00    High
# 7  2023-02-12          219     195.50    High
# 8  2023-02-26          255     241.00    High
# 9  2023-03-12          136     227.50  Medium
# 10 2023-03-26          210     205.00    High
# 11 2023-04-02          131     183.00  Medium
# 12 2023-04-23          112     147.25  Medium
# 13 2023-05-14          102     138.75  Medium
# 14 2023-05-21           86     107.75     Low
# 15 2023-05-28          138     109.50  Medium
# 16 2023-06-04          418     186.00    High
# 17 2023-06-11          113     188.75  Medium
# 18 2023-06-18          150     204.75  Medium
# ...
